# %%
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt

# %%
adata = sc.read_h5ad('../data/test_workflow4/HVG/0.1_resultFile/0.1_res_pred.h5ad')
adata.obs_names_make_unique()

# %%
root = []
typecsv = pd.read_csv('../data/test_workflow4/HVG/0.1_resultFile/celltype.txt')
for i in range(typecsv.shape[1]):
    root.append(typecsv.iloc[0,i])

# %%
fig, ax = plt.subplots()

sc.pl.paga(adata, color=['leiden'],fontsize=8, fontweight=1,ax=ax, show=False)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# %%
sc.tl.paga(adata, groups='leiden')
color = list(adata.var_names)[:10]
sc.pl.paga(adata, color=['leiden'], save='_leiden', fontsize=8, fontweight=10)

sc.pl.paga(adata, color=['leiden'], save='_colorGene')
sc.pl.paga(adata, color=color, save='_colorGene')

sc.pl.paga_compare(
    adata, threshold=0.03, title='', right_margin=0.2, size=10, edge_width_scale=0.5,
    legend_fontsize=12, fontsize=12, frameon=False, edges=True, save='_compare', legend_fontoutline=1)

# for ro in root:
#     adata.uns['iroot'] = np.flatnonzero(adata.obs['leiden'] == ro)[0]
#     sc.tl.dpt(adata)
#     sc.tl.draw_graph(adata, init_pos='paga')
#     sc.pl.draw_graph(adata, color=['leiden', 'dpt_pseudotime'], legend_loc='on data', save=ro + '_fr_'+config['annotation']['method'], size=10)
# Out:
# WARNING: saving figure to file figures/paga_leiden.pdf
# WARNING: saving figure to file figures/paga_colorGene.pdf
# WARNING: saving figure to file figures/paga_colorGene.pdf
# /nfs02data1/home/caikangwen/anaconda3/envs/sc/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 8
#       5 sc.pl.paga(adata, color=['leiden'], save='_colorGene')
#       6 sc.pl.paga(adata, color=color, save='_colorGene')
# ----> 8 sc.pl.paga_compare(
#       9     adata, threshold=0.03, title='', right_margin=0.2, size=10, edge_width_scale=0.5,
#      10     legend_fontsize=12, fontsize=12, frameon=False, edges=True, save='_compare', legend_fontoutline=1)
#
# ...
